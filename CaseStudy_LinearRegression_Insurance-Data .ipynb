# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df  = pd.read_csv('new_insurance_data (1).csv')
df
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
#       num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 0         715428.0          4.720921e+06                              0.0
# 1         699157.0          4.329832e+06                              0.0
# 2         702341.0          6.884861e+06                              0.0
# 3         700250.0          4.274774e+06                              0.0
# 4         711584.0          3.787294e+06                              0.0
# ...            ...                   ...                              ...
# 1333     1091267.0          1.703805e+08                              2.0
# 1334     1107872.0          2.015152e+08                              2.0
# 1335     1092005.0          2.236450e+08                              2.0
# 1336     1106821.0          2.528924e+08                              3.0
# 1337     1100328.0          2.616317e+08                              3.0
#
#       Anual_Salary     region      charges
# 0     5.578497e+07  southeast   1121.87390
# 1     1.370089e+07  southeast   1131.50660
# 2     7.352311e+07  southeast   1135.94070
# 3     7.581968e+07  southeast   1136.39940
# 4     2.301232e+07  southeast   1137.01100
# ...            ...        ...          ...
# 1333  3.101107e+09  northwest  55135.40209
# 1334  3.484216e+09  northeast  58571.07448
# 1335  3.640807e+09  northwest  60021.39897
# 1336  4.006359e+09  southeast  62592.87309
# 1337  4.117197e+09  southeast  63770.42801
#
# [1338 rows x 13 columns]

# %% [markdown]
# ### EDA

# %%
df.shape
# Out:
# (1338, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1329 non-null   float64
#  1   sex                              1338 non-null   object
#  2   bmi                              1335 non-null   float64
#  3   children                         1333 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1324 non-null   float64
#  6   past_consultations               1332 non-null   float64
#  7   num_of_steps                     1335 non-null   float64
#  8   Hospital_expenditure             1334 non-null   float64
#  9   NUmber_of_past_hospitalizations  1336 non-null   float64
#  10  Anual_Salary                     1332 non-null   float64
#  11  region                           1338 non-null   object
#  12  charges                          1338 non-null   float64
# dtypes: float64(10), object(3)
# memory usage: 136.0+ KB

# %%
# checked null values 
df.isnull().sum()
# Out:
# age                                 9
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %%
# Dropped null Values 
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# age                                0
# sex                                0
# bmi                                0
# children                           0
# smoker                             0
# Claim_Amount                       0
# past_consultations                 0
# num_of_steps                       0
# Hospital_expenditure               0
# NUmber_of_past_hospitalizations    0
# Anual_Salary                       0
# region                             0
# charges                            0
# dtype: int64

# %%
# check duplicates 
df.duplicated().sum()

#   df.drop_duplicates()  : to remove duplicates
# Out:
# 0

# %% [markdown]
# ### Visualisation

# %%
 # for reference : all the columns in one output 
col = df.columns
col
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges'],
#       dtype='object')

# %%
# Histograph 
plt.figure(figsize=(5, 3))
plt.hist(df['age'])
plt.xlabel('age')
plt.ylabel('count')
plt.show()

# %%
# statistical comopnent  analysis 
df.describe().T
# Out:
#                                   count          mean           std  \
# age                              1287.0  3.941958e+01  1.405199e+01
# bmi                              1287.0  3.065575e+01  6.086323e+00
# children                         1287.0  1.094794e+00  1.202782e+00
# Claim_Amount                     1287.0  3.349858e+04  1.561172e+04
# past_consultations               1287.0  1.524709e+01  7.457366e+00
# num_of_steps                     1287.0  9.113778e+05  9.083364e+04
# Hospital_expenditure             1287.0  1.579929e+07  2.653821e+07
# NUmber_of_past_hospitalizations  1287.0  1.068376e+00  5.290789e-01
# Anual_Salary                     1287.0  3.727972e+08  5.655770e+08
# charges                          1287.0  1.336607e+04  1.202582e+04
#
#                                           min           25%           50%  \
# age                              1.800000e+01  2.700000e+01  4.000000e+01
# bmi                              1.596000e+01  2.622000e+01  3.036000e+01
# children                         0.000000e+00  0.000000e+00  1.000000e+00
# Claim_Amount                     2.912591e+03  2.090597e+04  3.396877e+04
# past_consultations               1.000000e+00  9.000000e+00  1.500000e+01
# num_of_steps                     6.991570e+05  8.489270e+05  9.152840e+05
# Hospital_expenditure             2.945253e+04  4.114357e+06  7.567064e+06
# NUmber_of_past_hospitalizations  0.000000e+00  1.000000e+00  1.000000e+00
# Anual_Salary                     3.150786e+06  7.964523e+07  1.451129e+08
# charges                          1.121874e+03  4.842251e+03  9.549565e+03
#
#                                           75%           max
# age                              5.100000e+01  6.400000e+01
# bmi                              3.460000e+01  5.313000e+01
# children                         2.000000e+00  5.000000e+00
# Claim_Amount                     4.515241e+04  7.727799e+04
# past_consultations               2.000000e+01  4.000000e+01
# num_of_steps                     9.726140e+05  1.107872e+06
# Hospital_expenditure             1.093014e+07  2.616317e+08
# NUmber_of_past_hospitalizations  1.000000e+00  3.000000e+00
# Anual_Salary                     3.337660e+08  4.117197e+09
# charges                          1.696413e+04  6.377043e+04

# %%
# Detecting Outliers and IQR

# %%
col
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges'],
#       dtype='object')

# %%
# Code that gives box plots for all the columns whre datatype isn't object 

for itr in col:
    if (df[itr].dtypes == 'int64' or df[itr].dtypes == 'float64'):
        plt.boxplot(df[itr])
        plt.xlabel(itr)
        plt.ylabel('Outliers')
        plt.show()

# %%
# removal of outliers using IQR method
# Out:
# 12.450000000000001

# %%
# creat Q3, Q1,IQR
# Use the condition of outliers : All the datapoints Below lower fence and Above Upper Fence  are known as ouotliers
# So use the opposite/ Reversal ofthe above condition in order to remove 

# outliers = df['age']< lf & df['age']> uf
     # reverse the above condition 
# no outliers /only pure data = df['age']>lf & df['age']<uf

# %%
# make a not ao all the columns with outliers 

# bmi, past_consultations, Hospital_expenditure, NUmber_of_past_hospitalizations, Anual_Salary, charges

# %%
# For bmi column

Q1 = df.bmi.quantile(0.25)
Q3 = df.bmi.quantile(0.75)

IQR = Q3-Q1
IQR

# Filtering out the outliers by applying the reversal of the Technique 

df = df[(df.bmi >= Q1 -1.5*(IQR)) & (df.bmi <= Q3+1.5*(IQR))]
# Out:
# 8.380000000000003

# %%
col
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges'],
#       dtype='object')

# %%
# Using For Loop Removal of Outliers 
for i in col:
  if (df[i].dtypes == 'int64' or df[i].dtypes == 'float64'):
    Q1 = df[i].quantile(0.25)
    Q3 =  df[i].quantile(0.75)
    IQR = Q3-Q1
    df = df[(df[i]>= Q1 - (1.5 * IQR)) & (df[i] <= Q3 + (1.5 * IQR))]

# %%
# verify 

for itr in col:
    if (df[itr].dtypes == 'int64' or df[itr].dtypes == 'float64'):
        plt.boxplot(df[itr])
        plt.xlabel(itr)
        plt.ylabel('Outliers')
        plt.show()

# %%
corr = df.corr(numeric_only = True)
corr
# Out:
#                                       age       bmi  children  Claim_Amount  \
# age                              1.000000  0.185847 -0.161827      0.082596
# bmi                              0.185847  1.000000 -0.005243      0.003727
# children                        -0.161827 -0.005243  1.000000     -0.002322
# Claim_Amount                     0.082596  0.003727 -0.002322      1.000000
# past_consultations               0.168026  0.002038  0.008406      0.044025
# num_of_steps                     0.769073  0.080379 -0.009081      0.161479
# Hospital_expenditure             0.166197  0.029992 -0.065694      0.010152
# NUmber_of_past_hospitalizations       NaN       NaN       NaN           NaN
# Anual_Salary                     0.590401  0.052500 -0.070351      0.119414
# charges                          0.724307  0.055513 -0.049486      0.156393
#
#                                  past_consultations  num_of_steps  \
# age                                        0.168026      0.769073
# bmi                                        0.002038      0.080379
# children                                   0.008406     -0.009081
# Claim_Amount                               0.044025      0.161479
# past_consultations                         1.000000      0.235500
# num_of_steps                               0.235500      1.000000
# Hospital_expenditure                       0.060950      0.271380
# NUmber_of_past_hospitalizations                 NaN           NaN
# Anual_Salary                               0.231024      0.829880
# charges                                    0.242237      0.962305
#
#                                  Hospital_expenditure  \
# age                                          0.166197
# bmi                                          0.029992
# children                                    -0.065694
# Claim_Amount                                 0.010152
# past_consultations                           0.060950
# num_of_steps                                 0.271380
# Hospital_expenditure                         1.000000
# NUmber_of_past_hospitalizations                   NaN
# Anual_Salary                                 0.302673
# charges                                      0.303321
#
#                                  NUmber_of_past_hospitalizations  \
# age                                                          NaN
# bmi                                                          NaN
# children                                                     NaN
# Claim_Amount                                                 NaN
# past_consultations                                           NaN
# num_of_steps                                                 NaN
# Hospital_expenditure                                         NaN
# NUmber_of_past_hospitalizations                              NaN
# Anual_Salary                                                 NaN
# charges                                                      NaN
#
#                                  Anual_Salary   charges
# age                                  0.590401  0.724307
# bmi                                  0.052500  0.055513
# children                            -0.070351 -0.049486
# Claim_Amount                         0.119414  0.156393
# past_consultations                   0.231024  0.242237
# num_of_steps                         0.829880  0.962305
# Hospital_expenditure                 0.302673  0.303321
# NUmber_of_past_hospitalizations           NaN       NaN
# Anual_Salary                         1.000000  0.897165
# charges                              0.897165  1.000000

# %%
# Plotting the heatmap
plt.figure(figsize=(10, 4))  # Adjust the figure size as needed
sns.heatmap(corr, cmap='coolwarm', annot=True, fmt=".2f")
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %% [markdown]
# ## Model Building

# %%
# 1. Locate the Trget Columns and store it as 'y' (Dependent Variable/ Target Variable)

y = df.iloc[:,-1]    # last column is always the Trget column

# %%
# 2. To store all the feature other than the target in the independent variavle'x

x = df.loc[:, ['children','Claim_Amount','past_consultations','Hospital_expenditure','age' ]]

# %%
df
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 151   25.0    male  27.550       0.0     no   39148.95495                10.0
# 152   22.0  female  20.235       0.0     no   41547.52536                13.0
# 153   25.0    male  35.625       0.0     no   39660.60193                12.0
# 154   20.0    male  31.130       2.0     no   16032.87148                 7.0
# 155   21.0  female  17.400       1.0     no   31090.98977                21.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1007  26.0    male  27.060       0.0    yes   25808.79593                21.0
# 1009  20.0  female  26.840       1.0    yes   35909.40412                13.0
# 1013  19.0    male  29.070       0.0    yes   58901.21861                16.0
# 1014  30.0    male  22.990       2.0    yes   42204.03781                23.0
# 1019  28.0    male  23.980       3.0    yes   41686.19886                12.0
#
#       num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 151       780652.0          8.614147e+06                              1.0
# 152       802627.0          2.491594e+05                              1.0
# 153       770773.0          3.043323e+06                              1.0
# 154       769255.0          1.599069e+06                              1.0
# 155       778769.0          3.015365e+06                              1.0
# ...            ...                   ...                              ...
# 1007      960330.0          7.445284e+06                              1.0
# 1009      973322.0          1.113678e+07                              1.0
# 1013      975702.0          8.830423e+06                              1.0
# 1014      970426.0          5.963405e+06                              1.0
# 1019      974518.0          8.679934e+06                              1.0
#
#       Anual_Salary     region      charges
# 151   5.452601e+07  northwest   2523.16950
# 152   1.671847e+07  northwest   2527.81865
# 153   4.852694e+07  northwest   2534.39375
# 154   2.441262e+07  southeast   2566.47070
# 155   5.853579e+07  southwest   2585.26900
# ...            ...        ...          ...
# 1007  2.944865e+08  southeast  17043.34140
# 1009  3.058401e+08  southeast  17085.26760
# 1013  3.304683e+08  northwest  17352.68030
# 1014  3.045704e+08  northwest  17361.76610
# 1019  3.225795e+08  southeast  17663.14420
#
# [818 rows x 13 columns]

# %%
# 3. Splitting the Variable I.e x and y

#  variables x and y are split into 2 different cataories making it 4 variable in the end 
     #   x-train , x_test, y_train , y_test
  

      # training data is for actual values 
      # Testing data is for predicted values

# %%
# 4.  import the Algorith of Linear Regression 

from sklearn.linear_model import LinearRegression

# %%
#  created the Model and stored in the variable 'lr'
lr = LinearRegression()
lr
# Out:
# LinearRegression()

# %%
# .fit methos is used to provide date to the machine (training date )
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# using the test variables : perfomr prediction of results : predicted outcomes

# %%
# create a variavle  and make use .predict with x_test
# this gives us the output values that are predicted  outputs that recieved from trainig data

# %%
pred = lr.predict(x_test)
pred
# Out:
# array([10234.59016712,  8901.3830128 ,  6223.03346254, 11530.41673759,
#         7665.86168003,  6229.95205337,  7487.85910161, 11548.03269817,
#         4504.32918887, 10721.86509422,  8649.7141806 ,  8924.71158619,
#         9089.40462765,  9545.16659295,  7354.75147981,  3367.6460992 ,
#        12095.05920174,  9399.01277421, 11217.72576302, 12842.06895831,
#         5517.22124707, 12428.50337952,  9200.00736121, 11461.25053674,
#         8467.30921666,  9999.05123342, 10764.94353878,  7553.92850947,
#         6311.9386088 , 10101.15098706,  5979.15291832,  7700.34086665,
#         7862.00868091,  9756.2565608 ,  7501.46356015,  5801.52731143,
#         6048.50339723,  4331.39947526,  8573.1189012 , 10995.97952293,
#        10954.61790798, 11005.2802397 ,  7625.2389933 , 10349.74652538,
#         9178.21270309,  8807.67057708, 12728.36563529,  5670.12019446,
#        11145.99438172,  8956.38613215,  7670.70792852,  6029.27948706,
#        11383.87246889, 11084.36454449,  4733.31522908, 10379.41000922,
#         4578.48376227,  8243.87932523, 11458.49097828,  3719.91114658,
#         7802.0064934 ,  9565.01088828, 11959.76826802,  4431.3627254 ,
#        12584.0496341 ,  3145.82276789, 10677.14636968,  5661.49207311,
#        10340.25586816,  9541.7030973 , 11166.67561615, 12571.42166002,
#         6526.1461293 ,  7118.38374614,  8180.6298977 ,  7178.3906131 ,
#         8813.79917689, 11807.48346099,  7561.69736292,  7816.28836416,
#        11995.77591207,  8868.79100646,  7342.49574795,  8212.78018015,
#         4425.14399068, 11304.46951745, 11350.74790099,  6994.38388898,
#        12782.65867294,  5519.83091627,  8053.17535681,  5929.48287202,
#         6773.22099129,  8587.35946122,  7715.9019885 ,  9700.30174849,
#         9927.69610431, 10773.34286457,  9247.29001323,  9753.93088459,
#        13783.37470793,  5934.71198723, 11279.13826167,  6874.87959942,
#        11424.88612692,  5465.76918203,  6811.23934515,  6864.25946463,
#        11501.73836309,  6886.24904989, 10639.15288378, 11287.16053329,
#         5546.0888265 ,  9250.27147178,  3789.8116108 ,  6420.98036827,
#        14500.95855514,  4531.70642116,  7198.59744934, 12374.08027659,
#        12453.61124907,  4227.54215504,  5722.0448092 ,  7700.73290567,
#         8960.83004308,  9619.1478566 ,  8295.99035228,  4891.3999583 ,
#         5275.52562834,  8315.76642712, 10079.51582468,  7981.69681279,
#         9698.69683319,  5165.97290464,  7557.64503655, 10126.46533245,
#        12209.30674569,  8460.11505861,  9426.21788073, 11022.75401963,
#        12820.28537378,  9884.93324181,  8608.17510042,  5569.45555509,
#         7738.64051559,  6865.7692303 ,  5987.17103766,  7742.05380054,
#         9864.47260674, 10059.8078052 ,  9810.90444417,  4704.98908933,
#         7049.83669126, 12309.20131692, 12281.0938207 ,  8220.1744907 ,
#         8421.42110765, 12465.0952641 ,  9553.84384486, 13306.20612853,
#         5631.33395243,  7592.45215035,  5573.42315603, 10681.26924787])

# %%
# Compare with y_test for better understanding of
# accuracy of the model built for the comparison of expected outputs and predicted outputs

# In short calculate r2s

# %%
from sklearn.metrics import *

# %%
score = r2_score(y_test, pred)
score
# Out:
# 0.6911409302533084

# %%
# conclusion 

#With an R-squared score of 69%, the model explains 69% of the variance in healthcare charges or insurance premiums based on the selected features. While this indicates a good level of predictive capability, there's still room for improvement. Further refinement and validation are recommended for better generalization and decision-making.
